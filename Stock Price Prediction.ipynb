# %% [markdown]
# # Stock Price Prediction
# by- A V BHAVYA

# %%
pip install numpy pandas quandl
# Out:
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (1.18.1)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: quandl in d:\anaconda3\lib\site-packages (3.6.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in d:\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in d:\anaconda3\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: six in d:\anaconda3\lib\site-packages (from quandl) (1.14.0)
# Requirement already satisfied: more-itertools in d:\anaconda3\lib\site-packages (from quandl) (8.2.0)
# Requirement already satisfied: requests>=2.7.0 in d:\anaconda3\lib\site-packages (from quandl) (2.22.0)
# Requirement already satisfied: inflection>=0.3.1 in d:\anaconda3\lib\site-packages (from quandl) (0.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl
import numpy as np
import pandas as pd
quandl.ApiConfig.api_key="5d4TeS6MH6diZgfgcXwP"

# %%
df = quandl.get("EOD/AAPL")

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1090.000000  1090.000000  1090.000000  1090.000000  1.090000e+03
# mean    194.564537   196.114735   193.016676   194.613130  3.605114e+07
# std     160.562848   161.812898   159.407381   160.647536  2.194473e+07
# min      90.000000    90.700000    89.470000    90.280000  5.704900e+06
# 25%     108.042500   108.942500   106.972500   108.007500  2.120714e+07
# 50%     121.585000   122.504950   120.640000   121.755000  3.248325e+07
# 75%     156.905000   157.809625   155.744975   156.515000  4.673778e+07
# max     649.900000   651.260000   644.470000   647.350000  1.895606e+08
#
#           Dividend        Split     Adj_Open     Adj_High      Adj_Low  \
# count  1090.000000  1090.000000  1090.000000  1090.000000  1090.000000
# mean      0.015642     1.005505    26.367551    26.578236    26.152043
# std       0.175122     0.181735     6.614490     6.640870     6.578682
# min       0.000000     1.000000    14.189776    14.561974    14.166335
# 25%       0.000000     1.000000    22.170235    22.433992    21.948836
# 50%       0.000000     1.000000    25.781510    26.055842    25.511496
# 75%       0.000000     1.000000    29.329099    29.541994    29.133958
# max       3.290000     7.000000    42.125703    42.628488    42.065561
#
#          Adj_Close    Adj_Volume
# count  1090.000000  1.090000e+03
# mean     26.373196  1.931334e+08
# std       6.616455  1.112891e+08
# min      14.258197  4.590369e+07
# 25%      22.201030  1.133450e+08
# 50%      25.789823  1.681963e+08
# 75%      29.362853  2.394642e+08
# max      42.440845  1.065523e+09

# %%
df
# Out:
#               Open     High      Low    Close      Volume  Dividend  Split  \
# Date
# 2013-09-03  493.10  500.600  487.350  488.580  11854600.0       0.0    1.0
# 2013-09-04  499.56  502.240  496.280  498.691  12322600.0       0.0    1.0
# 2013-09-05  500.25  500.680  493.640  495.270   8441700.0       0.0    1.0
# 2013-09-06  498.44  499.380  489.950  498.220  12840200.0       0.0    1.0
# 2013-09-09  505.00  507.920  503.480  506.170  12167400.0       0.0    1.0
# ...            ...      ...      ...      ...         ...       ...    ...
# 2017-12-21  174.17  176.020  174.100  175.010  20949896.0       0.0    1.0
# 2017-12-22  174.68  175.424  174.500  175.010  16349444.0       0.0    1.0
# 2017-12-26  170.80  171.470  169.679  170.570  33185536.0       0.0    1.0
# 2017-12-27  170.10  170.780  169.710  170.600  21498213.0       0.0    1.0
# 2017-12-28  171.00  171.850  170.480  171.080  16480187.0       0.0    1.0
#
#              Adj_Open   Adj_High    Adj_Low  Adj_
# 2017-12-22  42.022259  42.201241  41.978957  42.101646   65397776.0  0.527970
# 2017-12-26  41.088858  41.250038  40.819183  41.033528  132742144.0  1.050009
# 2017-12-27  40.920461  41.084047  40.826640  41.040745   85992852.0  0.627198
# 2017-12-28  41.136972  41.341454  41.011877  41.156217   65920748.0  0.800795
#
#             PCT_Change
# Date
# 2013-09-03   -0.916650
# 2013-09-04   -0.173953
# 2013-09-05   -0.995502
# 2013-09-06   -0.044138
# 2013-09-09    0.231683
# ...                ...
# 2017-12-21    0.482287
# 2017-12-22    0.188917
# 2017-12-26   -0.134660
# 2017-12-27    0.293945
# 2017-12-28    0.046784
#
# [1090 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Dividend      0
# Split         0
# Adj_Open      0
# Adj_High      0
# Adj_Low       0
# Adj_Close     0
# Adj_Volume    0
# HL_PCT        0
# PCT_Change    0
# dtype: int64

# %%
#creating dataframe with date and the target variable
data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])

print(data.index)

for i in range(0,len(data)):
    new_data['Date'][i] = data.index[0]
    new_data['Close'][i] = data['Close'][i]
    
new_data
# Out:
# DatetimeIndex(['2013-09-03', '2013-09-04', '2013-09-05', '2013-09-06',
#                '2013-09-09', '2013-09-10', '2013-09-11', '2013-09-12',
#                '2013-09-13', '2013-09-16',
#                ...
#                '2017-12-14', '2017-12-15', '2017-12-18', '2017-12-19',
#                '2017-12-20', '2017-12-21', '2017-12-22', '2017-12-26',
#                '2017-12-27', '2017-12-28'],
#               dtype='datetime64[ns]', name='Date', length=1090, freq=None)
#                      Date    Close
# 0     2013-09-03 00:00:00   488.58
# 1     2013-09-03 00:00:00  498.691
# 2     2013-09-03 00:00:00   495.27
# 3     2013-09-03 00:00:00   498.22
# 4     2013-09-03 00:00:00   506.17
# ...                   ...      ...
# 1085  2013-09-03 00:00:00   175.01
# 1086  2013-09-03 00:00:00   175.01
# 1087  2013-09-03 00:00:00   170.57
# 1088  2013-09-03 00:00:00    170.6
# 1089  2013-09-03 00:00:00   171.08
#
# [1090 rows x 2 columns]

# %%
# splitting into train and validation
train = new_data[:987]
valid = new_data[987:]

# shapes of training set
print('\n Shape of training set:')
print(train.shape)

# shapes of validation set
print('\n Shape of validation set:')
print(valid.shape)
# Out:
#  Shape of training set:
# (987, 2)
#
#  Shape of validation set:
# (103, 2)

# %%
preds = []
for i in range(0,valid.shape[0]):
    a = train['Close'][len(train)-248+i:].sum() + sum(preds)
    b = a/248
    preds.append(b)

# checking the results (RMSE value)
rms=np.sqrt(np.mean(np.power((np.array(valid['Close'])-preds),2)))
print('\n RMSE value on validation set:')
print(rms)
# Out:
#  RMSE value on validation set:
# 30.63554908805543
