# %% [markdown]
# # Bitcoin Price Prediction
# by-
#    A V BHAVYA

# %% [markdown]
# Data Collection.
#
# Dataset found at https://raw.githubusercontent.com/WidhyaOrg/datasets/master/bitcoin_dataset.csv

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/WidhyaOrg/datasets/master/bitcoin_dataset.csv")

# %%
pd.read_csv("https://raw.githubusercontent.com/WidhyaOrg/datasets/master/bitcoin_dataset.csv")
# Out:
#            Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0     2/17/2010           0.00000           2043200.0    0.000000e+00
# 1     2/18/2010           0.00000           2054650.0    0.000000e+00
# 2     2/19/2010           0.00000           2063600.0    0.000000e+00
# 3     2/20/2010           0.00000           2074700.0    0.000000e+00
# 4     2/21/2010           0.00000           2085400.0    0.000000e+00
# ...         ...               ...                 ...             ...
# 2901  1/27/2018       11524.77667          16830312.5    1.940000e+11
# 2902  1/28/2018       11765.71000          16832287.5    1.980000e+11
# 2903  1/29/2018       11212.65500          16834137.5    1.890000e+11
# 2904  1/30/2018       10184.06167          16836225.0    1.710000e+11
# 2905  1/31/2018       10125.01333          16837687.5    1.700000e+11
#
#       btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0         0.000000e+00           0.0000            0.000235
# ...

# %%
df.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %% [markdown]
# To find the 1024th value in the column "btc_market_price"

# %%
val=df["btc_market_price"].values[1023]

# %%
val
# Out:
# 13.6888

# %% [markdown]
# Exploratory Data Analysis.
#
# Start by using jointplots to analyse the data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We will calculate our data correlation matrix using the Pearson Correlation Cofficient defined as:
#
# ρX,Y=cov(X,Y)/σXσY
#
#
# Where  cov(X,Y)  is the covariance between feature  X  and  Y  and  σX  is is the standard deviation of feature  X .
#
# This Value ranges between +1 and -1.
# With +1 being total direct correlation, -1 represeting total inverse correlation and 0 meaning no correlation at all.

# %%
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='RdYlGn', linewidths=0.2, yticklabels=True, fmt='.2f')
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.show()

# %% [markdown]
# If we look at the correlation between our target variable (btc_market_price) with the rest of the features we can get rid of features that don't influence our target variable, which are the ones whose correlation coefficient is close to 0.

# %%
# Drop useless features
df.drop(['btc_cost_per_transaction_percent', 'btc_n_orphaned_blocks', 'btc_estimated_transaction_volume'], axis=1,
       inplace=True)

# %% [markdown]
# Feature that shows a perfect correlation with 'btc_market_price' i.e that has a pearsonr equal to 1
#
# btc_market_cap

# %% [markdown]
# Data Cleaning.
#
# The first thing i like to do when preprocessing my data is to check for NAN values.

# %%
# Check for NANs values
nans = df.isna().sum()

# %%
nans[nans > 0]
# Out:
# btc_total_bitcoins              27
# btc_trade_volume                21
# btc_blocks_size                 29
# btc_median_confirmation_time    12
# btc_difficulty                  16
# btc_transaction_fees            10
# dtype: int64

# %% [markdown]
# There are multiple ways of dealing with NAN values. If you only a couple of samples which some attribute is a NAN, you might just be better off with dropping those samples entirely.
# Or if there are many then we can use a pandas function that will allow you to fill values in column that have NAN values.
# We use fillna()

# %%
df['btc_total_bitcoins'].mean()
# Out:
# 11511375.720736368

# %%
# Replace NaNs in column btc_total_bitcoins with the mean of values in the same column
df['btc_total_bitcoins'].fillna(value=df['btc_total_bitcoins'].mean(), inplace=True)
df['btc_trade_volume'].fillna(value=df['btc_trade_volume'].mean(), inplace=True)
df['btc_blocks_size'].fillna(value=df['btc_blocks_size'].mean(), inplace=True)
df['btc_median_confirmation_time'].fillna(value=df['btc_median_confirmation_time'].mean(), inplace=True)
df['btc_difficulty'].fillna(value=df['btc_difficulty'].mean(), inplace=True)
df['btc_transaction_fees'].fillna(value=df['btc_transaction_fees'].mean(), inplace=True)

# %%
nans= df.isna().sum()
nans[nans > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# So, now in that particular column all the NAN values are replaced by the mean of that column.

# %% [markdown]
# Model Formulation and Prediction
#
#
# RMSE
#
# The RMSE is a measure of the quality of an estimator and represents the distance from the actual values to the predicted ones. It is given by the formula:
#
# RMSE=1n∑i=1n(Yi−Y^)2−−−−−−−−−−−−√
#
# Where  n  is the number of samples,  Yi  is the actual value and  Y^  is the predicted value.
# This gives us an idea of how close to each other the predicted and actual values are, so the smaller the RMSE, the better.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Drop features that make the problem too easy
df.drop(['Date', 'btc_output_volume', 'btc_market_cap', 'btc_miners_revenue', 
         'btc_estimated_transaction_volume_usd'], axis=1, inplace=True) # Also drop Date which is a string

# %%
# split data into train and validation
x = df.iloc[:,1:].values
y = df.iloc[:, 0].values
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# Train a simple Linear Regressor with our data
model = LinearRegression(n_jobs=-1)
model.fit(x_train, y_train)
y_pred = model.predict(x_val)

# %% [markdown]
# Residual Plot
#
# A very useful well to visualize the robustness of a regressor is by using a residual plot. Which will give us an insight unto how biased our model can be.

# %%
#plot residual plot
xmin = min(int(np.min(model.predict(x_val))), int(np.min(model.predict(x_train))))
xmax = max(int(np.max(model.predict(x_val))), int(np.max(model.predict(x_train))))

# Visualize the results with a residual plot
plt.scatter(model.predict(x_train), model.predict(x_train) - y_train, label='Training')
plt.scatter(model.predict(x_val), model.predict(x_val) - y_val, label='Validation')
plt.hlines(y=0, xmin=xmin, xmax=xmax)
plt.title("Residual plot using training and validation data")
plt.gcf().set_size_inches(15, 10)
plt.legend()
plt.show()

# %%
print(np.sqrt(mean_squared_error(y_val, y_pred)))
# Out:
# 536.0126038509487

# %%
np.sqrt(mean_squared_error(y_val, y_pred)).round()
# Out:
# 536.0

# %%
print(r2_score(y_val,y_pred))
# Out:
# 0.9404647403276399
