# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("Data.csv")
df
# Out:
#                                                College  \
# 0                                                JDIET
# 1    Indian Institute of Information Technology Des...
# 2                     Manipal Institute of technology
# 3                       Delhi Technological Univeesity
# 4                         Jabalpur Engineering College
# ..                                                 ...
# 150        The LNM Institute of Information Technology
# 151              pandit deendayal petroleum university
# 152                                                MEC
# 153        Lal Bahadur Shastri Institute of Management
# 154                        Bms institute of technology
#
#      Flutter (skill out of 5)  Flask (skill out of 5)  \
# 0                         2.0                     4.0
# 1                         4.0                     1.0
# 2                         2.0                     2.0
# 3                         NaN                     4.0
# ...

# %%
df.describe()
# Out:
#        Flutter (skill out of 5)  Flask (skill out of 5)  \
# count                138.000000              136.000000
# mean                   1.768116                1.992647
# std                    1.082642                1.125439
# min                    1.000000                1.000000
# 25%                    1.000000                1.000000
# 50%                    1.000000                2.000000
# 75%                    2.750000                3.000000
# max                    5.000000                5.000000
#
#        Firebase (skill out of 5)  GCP (skill out of 5)  AWS (skill out of 5)  \
# count                 138.000000            132.000000            130.000000
# mean                    1.992754              1.643939              1.884615
# std                     1.117194              0.925735              1.008757
# min                     1.000000              1.000000              1.000000
# ...

# %%
df.isna().sum()
# Out:
# College                                   0
# Flutter (skill out of 5)                 17
# Flask (skill out of 5)                   19
# Firebase (skill out of 5)                17
# GCP (skill out of 5)                     23
# AWS (skill out of 5)                     25
# Predictive Modelling (skill out of 5)    11
# EDA (skill out of 5)                     11
# NLP (skill out of 5)                     20
# dtype: int64

# %%
df = df.replace(np.nan,1, regex=True) # All data frame

# %%
dn=df.loc[df['College'] == 'Gitam university, Vizag']
dn=dn.drop(columns=['College'])
dn
# Out:
#     Flutter (skill out of 5)  Flask (skill out of 5)  \
# 74                       1.0                     1.0
#
#     Firebase (skill out of 5)  GCP (skill out of 5)  AWS (skill out of 5)  \
# 74                        1.0                   1.0                   3.0
#
#     Predictive Modelling (skill out of 5)  EDA (skill out of 5)  \
# 74                                    3.0                   4.0
#
#     NLP (skill out of 5)
# 74                   2.0

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = ['Flutter','Flask','GCP','AWS','PM','EDA','NLP']
students = [1.0,1.0,1.0,3.0,3.0,4.0,2.0]
ax.pie(students, labels = langs,autopct='%1.9f%%')
plt.show()

# %%
df
# Out:
#                                                College  \
# 0                                                JDIET
# 1    Indian Institute of Information Technology Des...
# 2                     Manipal Institute of technology
# 3                       Delhi Technological Univeesity
# 4                         Jabalpur Engineering College
# ..                                                 ...
# 150        The LNM Institute of Information Technology
# 151              pandit deendayal petroleum university
# 152                                                MEC
# 153        Lal Bahadur Shastri Institute of Management
# 154                        Bms institute of technology
#
#      Flutter (skill out of 5)  Flask (skill out of 5)  \
# 0                         2.0                     4.0
# 1                         4.0                     1.0
# 2                         2.0                     2.0
# 3                         NaN                     4.0
# ...

# %%
df.sum()
# Out:
# College                                  JDIETIndian Institute of Information Technolog...
# Flutter (skill out of 5)                                                               244
# Flask (skill out of 5)                                                                 271
# Firebase (skill out of 5)                                                              275
# GCP (skill out of 5)                                                                   217
# AWS (skill out of 5)                                                                   245
# Predictive Modelling (skill out of 5)                                                  405
# EDA (skill out of 5)                                                                   431
# NLP (skill out of 5)                                                                   331
# dtype: object
